# %%
pip install pandas numpy matplotlib seaborn scikit-learn xgboost lightgbm catboost imbalanced-learn shap streamlit
# Out:
# Requirement already satisfied: pandas in /home/asus/anaconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy in /home/asus/anaconda3/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: matplotlib in /home/asus/anaconda3/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: seaborn in /home/asus/anaconda3/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in /home/asus/anaconda3/lib/python3.12/site-packages (1.5.1)
# Requirement already satisfied: xgboost in /home/asus/anaconda3/lib/python3.12/site-packages (3.0.0)
# Requirement already satisfied: lightgbm in /home/asus/anaconda3/lib/python3.12/site-packages (4.6.0)
# Requirement already satisfied: catboost in /home/asus/anaconda3/lib/python3.12/site-packages (1.2.8)
# Requirement already satisfied: imbalanced-learn in /home/asus/anaconda3/lib/python3.12/site-packages (0.12.3)
# Requirement already satisfied: shap in /home/asus/anaconda3/lib/python3.12/site-packages (0.47.2)
# Requirement already satisfied: streamlit in /home/asus/anaconda3/lib/python3.12/site-packages (1.37.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/asus/anaconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/asus/anaconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/asus/anaconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/asus/anaconda3/lib/python3.12/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/asus/anaconda3/lib/python3.12/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/asus/anaconda3/lib/python3.12/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/asus/anaconda3/lib/python3.12/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/asus/anaconda3/lib/python3.12/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /home/asus/anaconda3/lib/python3.12/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/asus/anaconda3/lib/python3.12/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: scipy>=1.6.0 in /home/asus/anaconda3/lib/python3.12/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/asus/anaconda3/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/asus/anaconda3/lib/python3.12/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /home/asus/anaconda3/lib/python3.12/site-packages (from xgboost) (2.26.2.post1)
# Requirement already satisfied: graphviz in /home/asus/anaconda3/lib/python3.12/site-packages (from catboost) (0.20.3)
# Requirement already satisfied: plotly in /home/asus/anaconda3/lib/python3.12/site-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /home/asus/anaconda3/lib/python3.12/site-packages (from catboost) (1.16.0)
# Requirement already satisfied: tqdm>=4.27.0 in /home/asus/anaconda3/lib/python3.12/site-packages (from shap) (4.66.5)
# Requirement already satisfied: slicer==0.0.8 in /home/asus/anaconda3/lib/python3.12/site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /home/asus/anaconda3/lib/python3.12/site-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /home/asus/anaconda3/lib/python3.12/site-packages (from shap) (3.0.0)
# Requirement already satisfied: typing-extensions in /home/asus/anaconda3/lib/python3.12/site-packages (from shap) (4.11.0)
# Requirement already satisfied: altair<6,>=4.0 in /home/asus/anaconda3/lib/python3.12/site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in /home/asus/anaconda3/lib/python3.12/site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /home/asus/anaconda3/lib/python3.12/site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /home/asus/anaconda3/lib/python3.12/site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: protobuf<6,>=3.20 in /home/asus/anaconda3/lib/python3.12/site-packages (from streamlit) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in /home/asus/anaconda3/lib/python3.12/site-packages (from streamlit) (16.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /home/asus/anaconda3/lib/python3.12/site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /home/asus/anaconda3/lib/python3.12/site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /home/asus/anaconda3/lib/python3.12/site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in /home/asus/anaconda3/lib/python3.12/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /home/asus/anaconda3/lib/python3.12/site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /home/asus/anaconda3/lib/python3.12/site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /home/asus/anaconda3/lib/python3.12/site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog<5,>=2.1.5 in /home/asus/anaconda3/lib/python3.12/site-packages (from streamlit) (4.0.1)
# Requirement already satisfied: jinja2 in /home/asus/anaconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /home/asus/anaconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: toolz in /home/asus/anaconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/asus/anaconda3/lib/python3.12/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /home/asus/anaconda3/lib/python3.12/site-packages (from numba>=0.54->shap) (0.43.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/asus/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/asus/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/asus/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/asus/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/asus/anaconda3/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/asus/anaconda3/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in /home/asus/anaconda3/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/asus/anaconda3/lib/python3.12/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/asus/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/asus/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/asus/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/asus/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in /home/asus/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing libraries
import pandas as pd
import numpy as np

# Load the dataset
data = pd.read_csv('/home/asus/Desktop/churn_project/customer_churn.csv')

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB
# None

# %%
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter numeric columns
numeric_data = data.select_dtypes(include=[float, int])

# Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm')
plt.title('Feature Correlation')
plt.show()

# Churn Distribution
sns.countplot(x='Churn', data=data)
plt.title('Churn Distribution')
plt.show()

# %%
data_encoded = pd.get_dummies(data.sample(n=500, random_state=42), drop_first=True)

# %%
print(data_encoded.shape)  # (rows, columns)
# Out:
# (500, 1024)

# %%
data_encoded
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  customerID_0076-LVEPS  \
# 185               0       1           24.80                  False
# 2715              0      41           25.25                  False
# 3825              0      52           19.35                  False
# 1807              0       1           76.35                  False
# 132               0      67           50.55                  False
# ...             ...     ...             ...                    ...
# 4028              0      63          109.20                  False
# 3805              1       1           71.65                  False
# 228               0      30           89.90                  False
# 1467              0      23           73.75                  False
# 1978              0      57           69.75                  False
#
#       customerID_0078-XZMHT  customerID_0080-EMYVY  customerID_0080-OROZO  \
# 185                   False                  False                  False
# 2715                  False                  False                  False
# 3825                  False                  False                  False
# 1807                  False                  False                  False
# 132                   False                  False                  False
# ...                     ...                    ...                    ...
# 4028                  False                  False                  False
# 3805                  False                  False                  False
# 228                   False                  False                  False
# 1467                  False                  False                  False
# 1978                  False                  False                  False
#
#       customerID_0148-DCDOS  customerID_0187-WZNAB  customerID_0201-MIBOL  \
# 185                   False                  False                  False
# 2715                  False                  False                  False
# 3825                  False                  False                  False
# 1807                  False                  False                  False
# 132                   False                  False                  False
# ...                     ...                    ...                    ...
# 4028                  False                  False                  False
# 3805                  False                  False                  False
# 228                   False                  False                  False
# 1467                  False                  False                  False
# 1978                  False                  False                  False
#
#       ...  TotalCharges_96.85  TotalCharges_966.55  TotalCharges_970.45  \
# 185   ...               False                False                False
# 2715  ...               False                False                False
# 3825  ...               False                False                False
# 1807  ...               False                False                False
# 132   ...               False                False                False
# ...   ...                 ...                  ...                  ...
# 4028  ...               False                False                False
# 3805  ...               False                False                False
# 228   ...               False                False                False
# 1467  ...               False                False                False
# 1978  ...               False                False                False
#
#       TotalCharges_973.45  TotalCharges_973.95  TotalCharges_978  \
# 185                 False                False             False
# 2715                False                False             False
# 3825                False                False             False
# 1807                False                False             False
# 132                 False                False             False
# ...                   ...                  ...               ...
# 4028                False                False             False
# 3805                False                False             False
# 228                 False                False             False
# 1467                False                False             False
# 1978                False                False             False
#
#       TotalCharges_982.95  TotalCharges_996.45  TotalCharges_997.65  Churn_Yes
# 185                 False                False                False       True
# 2715                False                 True                False      False
# 3825                False                False                False      False
# 1807                False                False                False       True
# 132                 False                False                False      False
# ...                   ...                  ...                  ...        ...
# 4028                False                False                False      False
# 3805                False                False                False       True
# 228                 False                False                False      False
# 1467                False                False                False      False
# 1978                False                False                False      False
#
# [500 rows x 1024 columns]

# %%
# Limit to 30 columns max (arbitrary)
limited_data = data_encoded.iloc[:, :30]  
plt.figure(figsize=(12, 8))
sns.heatmap(limited_data.corr(), annot=True, cmap='coolwarm')
plt.title('Feature Correlation (subset)')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(data_encoded.corr(), cmap='coolwarm')  # Removed annot=True
plt.title('Feature Correlation')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# Encoding categorical variables
le = LabelEncoder()
for col in data.select_dtypes(include=['object']).columns:
    data[col] = le.fit_transform(data[col])

# Feature and Target Split
X = data.drop(columns=["customerID", "Churn"])
y = data['Churn']


# Feature Selection using RFE
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
rfe = RFE(model, n_features_to_select=15)
fit = rfe.fit(X, y)

selected_features = X.columns[fit.support_]
X = X[selected_features]

print("Selected Features:", selected_features)
# Out:
# Selected Features: Index(['gender', 'SeniorCitizen', 'Partner', 'tenure', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges'],
#       dtype='object')

# %%
from imblearn.combine import SMOTEENN

# Balancing the data
smote_enn = SMOTEENN(random_state=42)
X_resampled, y_resampled = smote_enn.fit_resample(X, y)

print('Before balancing:', np.bincount(y))
print('After balancing:', np.bincount(y_resampled))
# Out:
# Before balancing: [5174 1869]
# After balancing: [2752 3148]

# %%
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# Models
models = {
    'XGBoost': XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
    'LightGBM': LGBMClassifier(),
    'CatBoost': CatBoostClassifier(verbose=0)
}

# Training
for name, model in models.items():
    model.fit(X_train, y_train)
    print(f'{name} trained successfully!')
# Out:
# /home/asus/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [17:30:21] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBoost trained successfully!
# [LightGBM] [Info] Number of positive: 2529, number of negative: 2191
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000450 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 616
# [LightGBM] [Info] Number of data points in the train set: 4720, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.535805 -> initscore=0.143466
# [LightGBM] [Info] Start training from score 0.143466
# LightGBM trained successfully!
# CatBoost trained successfully!

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve

# Evaluate models
for name, model in models.items():
    y_pred = model.predict(X_test)
    print(f'\n{name} Model Evaluation:')
    print(classification_report(y_test, y_pred))
    print('AUC-ROC:', roc_auc_score(y_test, model.predict_proba(X_test)[:,1]))
# Out:
# XGBoost Model Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95       561
#            1       0.94      0.97      0.96       619
#
#     accuracy                           0.95      1180
#    macro avg       0.96      0.95      0.95      1180
# weighted avg       0.95      0.95      0.95      1180
#
# AUC-ROC: 0.9930570553966924
#
# LightGBM Model Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95       561
#            1       0.94      0.98      0.96       619
#
#     accuracy                           0.95      1180
#    macro avg       0.96      0.95      0.95      1180
# weighted avg       0.95      0.95      0.95      1180
#
# AUC-ROC: 0.9933090287076793
#
# CatBoost Model Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       561
#            1       0.95      0.97      0.96       619
#
#     accuracy                           0.95      1180
#    macro avg       0.95      0.95      0.95      1180
# weighted avg       0.95      0.95      0.95      1180
#
# AUC-ROC: 0.991732395704647

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve

# Evaluate models
for name, model in models.items():
    y_pred = model.predict(X_test)
    print(f'\n{name} Model Evaluation:')
    print(classification_report(y_test, y_pred))
    print('AUC-ROC:', roc_auc_score(y_test, model.predict_proba(X_test)[:,1]))
# Out:
# XGBoost Model Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95       561
#            1       0.94      0.97      0.96       619
#
#     accuracy                           0.95      1180
#    macro avg       0.96      0.95      0.95      1180
# weighted avg       0.95      0.95      0.95      1180
#
# AUC-ROC: 0.9930570553966924
#
# LightGBM Model Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95       561
#            1       0.94      0.98      0.96       619
#
#     accuracy                           0.95      1180
#    macro avg       0.96      0.95      0.95      1180
# weighted avg       0.95      0.95      0.95      1180
#
# AUC-ROC: 0.9933090287076793
#
# CatBoost Model Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       561
#            1       0.95      0.97      0.96       619
#
#     accuracy                           0.95      1180
#    macro avg       0.95      0.95      0.95      1180
# weighted avg       0.95      0.95      0.95      1180
#
# AUC-ROC: 0.991732395704647

# %%
plt.figure(figsize=(10,6))

for name, model in models.items():
    fpr, tpr, _ = roc_curve(y_test, model.predict_proba(X_test)[:,1])
    plt.plot(fpr, tpr, label=name)

plt.plot([0,1],[0,1],'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Comparison')
plt.legend()
plt.show()

# %%
import shap

# SHAP values for best model (say XGBoost)
explainer = shap.TreeExplainer(models['XGBoost'])
shap_values = explainer.shap_values(X_test)

# Summary plot
shap.summary_plot(shap_values, X_test)

# %%
# Save the best model
import joblib
joblib.dump(models['XGBoost'], 'churn_model.pkl')
# Out:
# ['churn_model.pkl']

# %%
import pandas as pd
import joblib
from sklearn.preprocessing import LabelEncoder
import os

# Load your dataset
df = pd.read_csv("/home/asus/Desktop/churn_project/customer_churn.csv")  # Adjust path if necessary

# Drop customerID if it exists (not used for modeling)
if "customerID" in df.columns:
    df = df.drop(columns=["customerID"])

# Initialize dictionary to hold encoders
label_encoders = {}

# Loop through categorical columns and fit LabelEncoders
for col in df.select_dtypes(include="object").columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col].astype(str))
    label_encoders[col] = le

# Save the encoders
os.makedirs("models", exist_ok=True)
joblib.dump(label_encoders, "models/label_encoders.pkl")

print("✅ label_encoders.pkl created and saved in models/")
# Out:
# ✅ label_encoders.pkl created and saved in models/

# %%
joblib.dump(model, "models/xgboost_model.pkl")
# Out:
# ['models/xgboost_model.pkl']
